# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.6/876.6 kB 39.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/My Drive/Dataset2/data.yaml" epochs=5 imgsz=640 plots=True save=True save_period=300 device=0 project='YOLOv8' name='yolov8s_experiment' #resume=True
# Out:
# Ultralytics 8.3.14 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
saved_model_path = "/content/YOLOv8/yolov8s_experiment2/weights/best.pt"

# Destination path to save the model to Google Drive
drive_model_path = "/content/drive/My Drive/Dataset2/YOLO2/model_1.pt"

# Copy the model to Google Drive
# !cp "{saved_model_path}" "{drive_model_path}"

# %%
model=('YOLOv8/yolov8s_experiment2/weights/last_interrupt.pt')
model.save("/content/drive/My Drive/Dataset2/YOLO2/model_1.pt")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4b404302eac2> in <cell line: 2>()
#       1 model=('YOLOv8/yolov8s_experiment2/weights/last_interrupt.pt')
# ----> 2 model.save("/content/drive/My Drive/Dataset2/YOLO2/model_1.pt")
#
# AttributeError: 'str' object has no attribute 'save'

# %%
model2 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_1.pt')

# Resume training for 5 more epochs
try:
  model2.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=5,   # Continue training for 5 more epochs
      batch=16,
      imgsz=416,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model2.save('/content/drive/My Drive/Dataset2/YOLO2/model_2.pt')
    print("Training interrupted, model saved.")

model2.save('/content/drive/My Drive/Dataset2/YOLO2/model_2.pt')
# Out:
# Ultralytics 8.3.14 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model3 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_3.pt')

# Resume training for 5 more epochs
try:
  model3.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=5,   # Continue training for 5 more epochs
      batch=16,
      imgsz=640,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model3.save('/content/drive/My Drive/Dataset2/YOLO2/model_4.pt')
    print("Training interrupted, model saved.")

model3.save('/content/drive/My Drive/Dataset2/YOLO2/model_4.pt')
# Out:
# Ultralytics 8.3.14 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model4 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_4.pt')

# Resume training for 5 more epochs
try:
  model4.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=5,   # Continue training for 5 more epochs
      batch=16,
      imgsz=640,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model4.save('/content/drive/My Drive/Dataset2/YOLO2/model_5.pt')
    print("Training interrupted, model saved.")

model4.save('/content/drive/My Drive/Dataset2/YOLO2/model_5.pt')
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
 model5 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_5.pt')

# Resume training for 5 more epochs
try:
  model5.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=5,   # Continue training for 5 more epochs
      batch=16,
      imgsz=640,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model5.save('/content/drive/My Drive/Dataset2/YOLO2/model_6.pt')
    print("Training interrupted, model saved.")

model5.save('/content/drive/My Drive/Dataset2/YOLO2/model_6.pt')
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
 model6 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_6.pt')

# Resume training for 5 more epochs
try:
  model6.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=10,   # Continue training for 5 more epochs
      batch=16,
      imgsz=640,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model6.save('/content/drive/My Drive/Dataset2/YOLO2/model_7.pt')
    print("Training interrupted, model saved.")

model6.save('/content/drive/My Drive/Dataset2/YOLO2/model_7.pt')
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
 model7 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_7.pt')

# Resume training for 5 more epochs
try:
  model7.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=10,   # Continue training for 5 more epochs
      batch=16,
      imgsz=640,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model7.save('/content/drive/My Drive/Dataset2/YOLO2/model_8.pt')
    print("Training interrupted, model saved.")

model7.save('/content/drive/My Drive/Dataset2/YOLO2/model_8.pt')
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model8 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_8.pt')

# Resume training for 5 more epochs
try:
  model8.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=15,   # Continue training for 5 more epochs
      batch=16,
      imgsz=640,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model8.save('/content/drive/My Drive/Dataset2/YOLO2/model_9.pt')
    print("Training interrupted, model saved.")

model8.save('/content/drive/My Drive/Dataset2/YOLO2/model_9.pt')
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model9 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_9.pt')

# Resume training for 5 more epochs
try:
  model9.train(
      data="/content/drive/My Drive/Dataset2/data.yaml",  # Path to your dataset config
      epochs=15,   # Continue training for 5 more epochs
      batch=16,
      imgsz=640,
      device=0,
      #resume=True,  # This ensures it resumes from the last checkpoint
      project='YOLOv8',
      name='yolov8s_experiment2',
      save=True
)
except KeyboardInterrupt:
    model9.save('/content/drive/My Drive/Dataset2/YOLO2/model_10.pt')
    print("Training interrupted, model saved.")

model9.save('/content/drive/My Drive/Dataset2/YOLO2/model_10.pt')
# Out:
# Ultralytics 8.3.17 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model9 = YOLO('/content/drive/My Drive/Dataset2/YOLO2/model_10.pt')  # Make sure this is the path to the correct model

# Path to your test folder
test_folder = '/content/drive/My Drive/Dataset2/test/images'

# Run inference on the test dataset
results = model9.predict(
    source=test_folder,  # Path to the folder containing test images
    imgsz=640,           # Size of the input image
    conf=0.25,           # Confidence threshold for predictions
    save=True,           # Save the predicted images with bounding boxes
    save_txt=True,       # Save the predicted labels and boxes as text files
    device=0             # GPU device (if available)
)

# Display results
for result in results:
    print(result)
# Out:
# Streaming output truncated to the last 5000 lines.
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'annona', 1: 'apple', 2: 'banana', 3: 'beet', 4: 'bell_pepper', 5: 'cabbage', 6: 'carrot', 7: 'cucumber', 8: 'egg', 9: 'eggplant', 10: 'garlic', 11: 'guava', 12: 'onion', 13: 'orange', 14: 'pear', 15: 'pineapple', 16: 'pitaya', 17: 'potato', 18: 'tomato', 19: 'zucchini'}
# obb: None
# orig_img: array([[[226, 247, 249],
#         [226, 247, 249],
#         [227, 246, 249],
#         ...,
#         [199, 225, 232],
#         [199, 225, 232],
#         [199, 225, 232]],
#
#        [[226, 247, 249],
#         [226, 247, 249],
#         [227, 246, 249],
#         ...,
#         [199, 225, 232],
#         [199, 225, 232],
#         [199, 225, 232]],
#
#        [[227, 248, 250],
#         [227, 248, 250],
#         [228, 247, 250],
#         ...,
#         [199, 225, 232],
#         [199, 225, 232],
#         [199, 225, 232]],
#
#        ...,
#
# ...
